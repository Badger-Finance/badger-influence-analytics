# %% [markdown]
# ## Bribe and Voting report for bveCVX round 4th August 2022
#
# ---
#
# ### Snapshot Link
#
# [Snapshot Voting Round](https://vote.convexfinance.com/#/proposal/bafkreif6psu3omlhiuwlp5iryyl6vntnccevm5grlj5ugr7o6tefp26yae)
#
# ### Llama.Airforce:
#
# [Llama Airforce Link](https://llama.airforce/#/bribes/rounds/votium/cvx-crv/24)

# %% [markdown]
# ## Voting Results

# %%
from decimal import Decimal

import pandas as pd
from IPython.core.display_functions import display

from notebooks.cvx_bribes.bvecvx_data import VOTING_DATA_R24
from notebooks.cvx_bribes.bvecvx_data import get_rows_from_data

TABLE_COLUMNS = ["Total CVX $", "Total BADGER $", "Amount CVX bought", "Amount Badger bought",
                 "$/vlCVX total", "$/vlCVX pure bribes"]

table_rows = get_rows_from_data(VOTING_DATA_R24)
dataframe = pd.DataFrame(data=table_rows, columns=TABLE_COLUMNS)
display(dataframe)
llama_vlCVX = Decimal(0.09030)
badger_vlCVX = VOTING_DATA_R24['$/vlCVX without badgerwbtc']

print(f"\n")
print(f">>> Llama.Airforce $/vlCVX : ${round(llama_vlCVX, 3)}/vlCVX")
print(f">>> Badger $/vlCVX : ${badger_vlCVX}/vlCVX")
print(f">>> Difference is {round(abs(llama_vlCVX - badger_vlCVX) / ((llama_vlCVX + badger_vlCVX) / 2) * 100, 3)}%")
# Out:
#   Total CVX $ Total BADGER $ Amount CVX bought Amount Badger bought  \
# 0  142446.574      53399.085         20091.195            10288.841
#
#   $/vlCVX total $/vlCVX pure bribes
# 0         0.080               0.088
# >>> Llama.Airforce $/vlCVX : $0.090/vlCVX
# >>> Badger $/vlCVX : $0.088/vlCVX
# >>> Difference is 2.580%

# %% [markdown]
# ## Bribes harvesting info

# %%
from notebooks.cvx_bribes.bvecvx_data import BRIBES_HARVESTED_DATA_R24
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10, 10)

labels = tuple(BRIBES_HARVESTED_DATA_R24.keys())
pools_bribes = list(BRIBES_HARVESTED_DATA_R24.values())
biggest_bribe_by_vote = max(pools_bribes)
biggest_bribe_ix = pools_bribes.index(biggest_bribe_by_vote)
explode = []
# Explode biggest bribe by value
for bribe in pools_bribes:
    explode.append(0.1) if pools_bribes.index(bribe) == biggest_bribe_ix else explode.append(0)

fig1, ax1 = plt.subplots()
ax1.pie(pools_bribes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("Pools badger voted for, 4th Aug 2022")
plt.show()

# %% [markdown]
# ## Overall voting data
#
# Display performance of Badger vlCVX over different voting rounds

# %%
from notebooks.cvx_bribes.bvecvx_data import VOTING_DATASETS

import matplotlib.pyplot as plt

rounds = [dataset['round'] for dataset in VOTING_DATASETS]
vlcvxs = [float(dataset['$/vlCVX without badgerwbtc']) for dataset in VOTING_DATASETS]

fig = plt.figure(figsize=(10, 10))

# creating the bar plot
plt.bar(rounds, vlcvxs, color='blue', width=0.4)

plt.xlabel("Rounds")
plt.ylabel("$/vlCVX")
plt.title("$/vlCVX over different voting rounds")
plt.show()
